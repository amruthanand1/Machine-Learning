# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\admin\Desktop\berlin_final.csv', encoding = 'iso-8859-1')
df.head(5)
# Out:
#    purchase_price  living_space_m2  plot_area_in_m2  number_of_rooms  \
# 0       1125000.0           191.43           122.41              5.0
# 1        285000.0            56.00             0.00              2.0
# 2        420000.0            84.00             0.00              3.0
# 3       1097000.0           191.43             0.00              5.0
# 4        425000.0            75.34             0.00              2.5
#
#    floor_on  total_floors  bedroom  bathroom  renoveation  contruction_year  \
# 0         0             3        2         2            0              2021
# 1         0             0        0         0            0              1997
# 2         0             0        0         0            0              1997
# 3         0             3        3         2            0              2021
# 4         1             2        1         1            0              1968
#
#        furnish_quality category  pincode balkon terrasse garten Gaste-WC  \
# ...

# %%
df.columns.get_numeric
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-81334cc700e4> in <module>
# ----> 1 df.columns.get_numeric
#
# AttributeError: 'Index' object has no attribute 'get_numeric'

# %%
df[df['purchase_price_1'] == 0]
# Out:
#         ï»¿                                           features  \
# 7570  37572  ['Stufenloser Zugang', 'Stufenloser Zugang', '...
#
#       purchase_price_1  living_space_in_mÃÂ²  plot_area_in_mÃÂ²  \
# 7570               0.0                   98.0                 0.0
#
#       number_of_rooms_1  floor_1  total_floor_1  bedroom_1  bathroom_1  ...  \
# 7570                4.0        0              1          0           1  ...
#
#      purchase_price_update  category  pincode    city balkon terrasse garten  \
# 7570              98 mÃÂ²      HAUS    15537  Erkner     no       no     no
#
#      Gaste-WC Aufzug price
# 7570       no     no  -inf
#
# [1 rows x 30 columns]

# %%
from scipy.stats import norm
fig, ax = plt.subplots(figsize = (12, 8))
sns.distplot(df['purchase_price_1'], ax = ax, fit = norm)

# %%
df['price'] = np.log(df['purchase_price_1'])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.heatmap(df['price'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-88734bc4b645> in <module>
# ----> 1 sns.heatmap(df['price'])
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 537                           yticklabels, mask)
#     538
#     539     # Add the pcolormesh kwargs here
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     111         mask = _matrix_mask(data, mask)
#     112
# ...

# %%
df1[df1 == 0] = 1

# %%
pd.set_option('display.max_rows', None)
df1.isnum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-3d309982e4e8> in <module>
#       1 pd.set_option('display.max_rows', None)
# ----> 2 df1.isnum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isnum'

# %%
plt.scatter(df['price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-10b8fba9bd8e> in <module>
# ----> 1 plt.scatter(df['price'])
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
str1 = df[['living_space_in_mÃÂ²', 'purchase_price_1', 'number_of_rooms_1', 'floor_1', 'bedroom_1']]
str1 = np.log(str1)
sns.pairplot(str1)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2bab23441590> in <module>
#       1 str1 = df[['living_space_in_mÃÂ²', 'purchase_price_1', 'number_of_rooms_1', 'floor_1', 'bedroom_1']]
#       2 str1 = np.log(str1)
# ----> 3 sns.pairplot(str1)
#
# ...

# %%
k = 10 #number of variables for heatmap
cols = df.corr().nlargest(k, 'purchase_price_1')['purchase_price_1'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
sns.pairplot(df)

# %%
living_space_in_mÃÂ², floor_1, total_floor_1, bedroom_1, bathroom_1, purchase_price_1

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (15, 8))
sns.heatmap(df.isnull(),yticklabels=False,cbar=True,cmap="viridis", ax = ax)

# %%
c = df.corr().abs()
c

# %%
corr = df.corr()
kot = corr[corr>0.5]
plt.figure(figsize=(12,8))
sns.heatmap(kot, cmap="Greens", annot = True)

# %%
sns.pairplot(df)

# %%
#for col in df.columns:
sns.boxplot(df['purchase_price_1'])

# %%
df.columns

# %%
pd.set_option("display.max_rows", None)
print(df['features'].unique())

# %%
#fig, ax = plt.subplots(figsize = (15, 8))
#df.boxplot(by = 'bathroom_1', column = 'bedroom_1', ax = ax)
